# %%
pokemon_1={"name": "pikachu","type": "electric" ,"attack": 70 , "defence": 40 , "hp": 50}
pokemon_2={"name": "charizard","type": "fire" ,"attack": 80 , "defence": 80 , "hp": 100 }
pokemon_3={"name": "squirtle","type": "water" ,"attack": 50 , "defence": 60 , "hp": 60}
pokemon_4={"name": "mew","type": "psychic" ,"attack": 90 , "defence": 50 , "hp": 80}
pokemon_5={"name": "charmander","type": "fire" ,"attack": 85 , "defence": 45 , "hp": 50 }
pokemon_6={"name": "dragonite","type": "dragon" ,"attack": 120 , "defence": 70 , "hp": 150 }
pokemon_7={"name": "ratata","type": "normal" ,"attack": 30 , "defence": 30 , "hp": 40}
pokemon_8={"name": "pidgey","type": "normal" ,"attack": 10 , "defence": 10 , "hp": 55}
pokemon_9={"name": "venusaur","type": "grass" ,"attack": 70 , "defence": 80 , "hp": 150}
types={"fire":["grass","bug"],"water":["fire","ground"],"electric":["water","flying"],"dragon":["dragon"],"normal":[],"psychic":["fighting","poison"],"grass":["ground","water"]}
player_1=[pokemon_1,pokemon_2,pokemon_6,pokemon_8]
player_2=[pokemon_4,pokemon_9,pokemon_3,pokemon_7]
current_1=0
current_2=0

def findDifference(attacker, defender):
  #attacker and defender are pokemon dictionary
  print(f"{attacker['name']} fights {defender['name']} ")
  attack_amt=attacker["attack"]
  defence_amt=defender["defence"]
  effective=types[attacker["type"]]
  if defender["type"] in effective:
    attack_amt*=2
  differece=attack_amt-defence_amt
  return difference
  #return the difference

result=0
total=0
while current_1 <len(player_1) and current_2 < len(player_2) :
  attacker = player_1[current_1]
  defender = player_2[current_2]

  difference=findDifference(attacker,defender)
  if difference >0:
    player_2[current_2]["hp"]=player_2[current_2]["hp"]-difference
  else:
    player_2[current_2]["hp"]=player_2[current_2]["hp"]-10
  difference_2=findDifference(defender,attacker)
  if difference_2 >0:
    player_1[current_1]["hp"]=player_1[current_1]["hp"]-difference_2
  else:
   player_1[current_1]["hp"]=player_1[current_1]["hp"]-10
  print(f"{player_1[current_1]['name']}'s remaining hp is {player_1[current_1]['hp']}")
  print(f"{player_2[current_2]['name']}'s remaining hp is {player_2[current_2]['hp']}")
  if player_1[current_1]["hp"]<=0:
    current_1+=1
  if player_2[current_2]["hp"]<=0:
    current_2+=1

if current_2 >=len(player_2) and current_1 >=len(player_1):
  print("draw")
elif current_2 >=len(player_2):
  print("player_1 wins")
elif current_1 >=len(player_1):
  print("player_2 wins")
# Out:
# pikachu fights mew
# pikachu's remaining hp is 0
# mew's remaining hp is 60
# charizard fights mew
# charizard's remaining hp is 90
# mew's remaining hp is 30
# charizard fights mew
# charizard's remaining hp is 80
# mew's remaining hp is 0
# charizard fights venusaur
# charizard's remaining hp is 70
# venusaur's remaining hp is 70
# charizard fights venusaur
# charizard's remaining hp is 60
# venusaur's remaining hp is -10
# charizard fights squirtle
# charizard's remaining hp is 40
# squirtle's remaining hp is 40
# charizard fights squirtle
# charizard's remaining hp is 20
# squirtle's remaining hp is 20
# charizard fights squirtle
# charizard's remaining hp is 0
# squirtle's remaining hp is 0
# dragonite fights ratata
# dragonite's remaining hp is 140
# ratata's remaining hp is -50
# player_1 wins
