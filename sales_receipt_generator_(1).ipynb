# %% [markdown]
# <a href="https://colab.research.google.com/github/Jkennnn/Computing-personal-projects/blob/main/sales_receipt_generator_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 5.5
def total_cost(cost):
  total = cost * 1.09
  return total

def discount(cost):
  if cost>= 50 and cost< 100:
    new_cost=cost*0.95
  elif cost>=100:
    new_cost=cost*0.90
  else:
    new_cost=cost
  return new_cost

def reward_points(cost):
  points=cost*3
  return points

def vouchers(cost,first_name):
  if 25<cost<=50:
    code=(first_name[0:3]+"05PERCENT")
  elif cost>50:
    code=(first_name[0:3]+"10PERCENT")
  else:
    code="None"
  return code

name=input("Enter your first name: ")

cost=float(input("Enter your cost: "))

print("------receipt------")

total=total_cost(cost)

print(f"total cost = ${total:.2f}")

discounted_price=discount(total)

print(f"discounted cost = ${discounted_price:.2f}")

print(f"rewards point = {int(reward_points(discounted_price))}")

if discounted_price < 25:
  print("You need to spend over $25 for a voucher code.")
else:
  code=vouchers(discounted_price,name)
  print(f"your voucher code is {code}")

with open ("vouchercode.txt","w") as file: #file automatically closes after the with block
  file.write(code)

print(f"discounted cost = ${discounted_price:.2f}") #prints discounted price

print(f"rewards point = {int(rewards_point(discounted_price))}") #prints rewards

if discounted_price < 25:
  print("You need to sped over $25 for a voucher code.")
else:
  code=vouchers(discounted_price,name)
  print(f"your voucher code is {code}")

with open ("vouchercode.txt","w") as file: #file automatically closes after the with block
  file.write(code)
